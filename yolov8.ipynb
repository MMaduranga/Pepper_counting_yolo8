# %%
# !pip install ultralytics

# %%
# !pip install tqdm --upgrade

# %%
import os
import shutil
from tqdm.notebook import tqdm

# %%
test_img="D:/Data sets/hot banana pepper/New folder"

# %%
# # Train/val/test sets as
# ## 1) dir: path/to/imgs, 2) file: path/to/imgs.txt, or 3) list: [path/to/imgs1, path/to/imgs2, ..]


# #path: ../datasets/coco128  # dataset root dir
# train: D:/Data sets/hot banana pepper/train data/images/train  # train images (relative to 'path') 128 images
# val: D:/Data sets/hot banana pepper/train data/images/val # val images (relative to 'path') 128 images
# # test:  # test images (optional)

# # Classes
# nc: 1  # number of classes
# names: ['pepper']  # class names

# %%
import ultralytics

# %%
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.109  Python-3.10.11 torch-2.0.1+cpu CPU
# Setup complete  (12 CPUs, 19.8 GB RAM, 31.2/100.0 GB disk)

# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=C:/Users/MDW/Downloads/dataset.yaml epochs=10 imgsz=640 batch=8 project=C:/Users/MDW/Downloads/result name=pepper
# Out:
# ...
#
#   0%|          | 0.00/21.5M [00:00<?, ?B/s]
#   0%|          | 8.00k/21.5M [00:00<20:11, 18.6kB/s]
#   0%|          | 24.0k/21.5M [00:00<11:06, 33.8kB/s]
#   0%|          | 88.0k/21.5M [00:01<03:07, 120kB/s]
#   1%|          | 120k/21.5M [00:01<03:37, 103kB/s]
#   1%|          | 136k/21.5M [00:01<04:21, 85.7kB/s]
#   1%|          | 152k/21.5M [00:01<03:55, 95.0kB/s]
#   1%|          | 168k/21.5M [00:02<05:20, 69.8kB/s]
#   1%|          | 184k/21.5M [00:03<11:11, 33.3kB/s]
#   1%|          | 200k/21.5M [00:04<11:27, 32.5kB/s]
#   1%|          | 216k/21.5M [00:05<16:19, 22.8kB/s]
#   1%|1         | 232k/21.5M [00:06<16:57, 21.9kB/s]
#   1%|1         | 248k/21.5M [00:06<17:40, 21.1kB/s]
#   1%|1         | 264k/21.5M [00:07<18:11, 20.4kB/s]
#   1%|1         | 280k/21.5M [00:09<21:51, 17.0kB/s]
#   1%|1         | 296k/21.5M [00:10<23:12, 16.0kB/s]
#   1%|1         | 312k/21.5M [00:11<25:50, 14.4kB/s]
#   1%|1         | 328k/21.5M [00:13<30:13, 12.3kB/s]
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('best.pt')  # load a custom model

# Predict with the model
results = model('test/a61.png')
# Out:
# image 1/1 P:\Machine Learning\pepper_counting\test\a61.png: 640x640 (no detections), 293.9ms
# Speed: 15.6ms preprocess, 293.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)

# %%
# !yolo detect predict model=best.pt source='test/' conf=0.2
# Out:
# Ultralytics YOLOv8.0.109  Python-3.10.11 torch-2.0.1+cpu CPU
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients
#
# image 1/5 P:\Machine Learning\pepper_counting\test\a41.jpg: 640x480 6 peppers, 224.7ms
# image 2/5 P:\Machine Learning\pepper_counting\test\a43.jpg: 640x416 (no detections), 172.8ms
# image 3/5 P:\Machine Learning\pepper_counting\test\a54.jpg: 480x640 3 peppers, 236.0ms
# image 4/5 P:\Machine Learning\pepper_counting\test\a61.png: 640x640 (no detections), 286.2ms
# image 5/5 P:\Machine Learning\pepper_counting\test\a62.jpg: 480x640 1 pepper, 205.4ms
# Speed: 0.0ms preprocess, 225.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\predict2

# %%
for result in results:
    print(result.boxes.data.shape[0])
# Out:
# 0
